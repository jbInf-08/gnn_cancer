# %% [markdown]
# # GNN cancer — results (template)
#
# Regenerate figures and tables from your local `results/` and `data/processed/`
# after training (outputs are not committed; see `README.md`).

# %%
from pathlib import Path
import sys
ROOT = Path('..').resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import gnn_cancer
print('gnn_cancer', gnn_cancer.__version__)
